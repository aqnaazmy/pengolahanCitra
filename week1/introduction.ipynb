# %%
from skimage import color, io
from skimage.transform import rescale
import matplotlib.pyplot as plt

# %%
img1 = io.imread('../assets/cats.jpg')

plt.imshow(img1)
plt.show()

# %%
img2 = io.imread('../assets/flower.jpg')

plt.imshow(img2)
plt.show()

# %%
img3 = io.imread('../assets/panda.jpg')

plt.imshow(img3)
plt.show()

# %%
img4 = io.imread('../assets/poltekharber.png')

plt.imshow(img4)
plt.show()

# %%
img5 = io.imread('../assets/poltekharber-gray.jpg')

plt.imshow(img5)
plt.show()

# %%
plt.subplot(1,3,1); plt.imshow(img1)
plt.subplot(1,3,2); plt.imshow(img2)
plt.subplot(1,3,3); plt.imshow(img3)

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
